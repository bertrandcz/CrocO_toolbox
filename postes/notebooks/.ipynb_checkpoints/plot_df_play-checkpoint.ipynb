# %%
# %matplotlib inline
from postes.explore_obs import find_common_massif_obsbase
import matplotlib.pyplot as plt
import seaborn as sns

plt.close('all')
obsPath = '/home/cluzetb/assim_postes/obs_postes_1983_2019.csv'
obsPath = '/home/cluzetb/assim_postes/OBS_2010080100_2020021023_types1346789.csv'

df, listp, _, _ = find_common_massif_obsbase(obsPath, massifs=[8,9,12,13,15])
df = df/100.
# D. finalize (rename cols etc.)
df = df.rename(columns = {int(p.find('number').text): p.find('name').text for p in listp})
print('cols', df.columns)
print('number of observed posts:', len(df.columns))


#  E. Play.
corr = df.corr()


plt.figure(figsize = (7,15))
sns.heatmap(corr, vmin = -1, vmax = 1, center = 0, cmap = 'RdBu', xticklabels=True, yticklabels=True)


for col in df.columns:
    plt.figure()
    plt.scatter(df.index, df[col],)
    plt.title(col)
    plt.gcf().autofmt_xdate()
    plt.show()
# Out:
# 0         6
# 1         6
# 2         8
# 3         3
# 4         7
# 5         8
# 6         8
# 7         7
# 8         1
# 9         7
# 10        7
# 11        7
# 12        7
# 13        1
# 14        7
# 15        3
# 16        7
# 17        1
# 18        3
# 19        7
# 20        7
# 21        1
# 22        7
# 23        3
# 24        7
# 25        7
# 26        1
# 27        7
# 28        7
# 29        1
#          ..
# 818860    1
# 818861    1
# 818862    1
# 818863    1
# 818864    1
# 818865    8
# 818866    1
# 818867    8
# 818868    8
# 818869    1
# 818870    4
# 818871    8
# 818872    1
# 818873    1
# 818874    1
# 818875    1
# 818876    1
# 818877    1
# 818878    8
# 818879    8
# 818880    8
# 818881    8
# 818882    8
# 818883    8
# 818884    8
# 818885    8
# 818886    8
# 818887    8
# 818888    8
# 818889    8
# Name: type, dtype: int64
#  AGNELIN-EDFNIVO
#  AIGLETON-NIVOSE
#  ALBIEZ
#  ALLEMOND
#  ALPE-D'HUEZ
#  AURIS
#  AURIS-EN-OISANS
#  Auris en Oisans -S-
#  BARDONECCHIA_PIAN_DEL_
#  BESSE
#  BISSORTE-EDFNIVO
#  Bachat-Bouloud
#  Bourg d Oisans
#  CHAMROUSSE -S-
#  CHAMROUSSE ARSELLE
#  CHARDONNET-EDFNIVO
#  CHATEAU_BEAULARD
#  COL D'ORNON
#  COL DU BARIOZ
#  CORPS
#  Cervieres -S-
#  Chamrousse Niverolles
#  Chamrousse Robert
#  Col du Lac Blanc -S-
#  GALIBIER-NIVOSE
#  JARRIER
#  L Alpe d Huez (SATA)
#  L Alpe d Huez (SATA) -
#  L Alpe d Huez 2350
#  L Alpe d Huez 2350 -S-
#  L Alpe d Huez 2700
#  L Alpe du Grand Serre
#  L Alpe du Grand Serre
#  LA MEIJE-NIVOSE
#  LA SALETTE
#  LAC NOIR-EDFNIVO
#  LAVALDENS
#  LES ECRINS-NIVOSE
#  LES ROCHILLES-NIVOSE
#  La Berarde
#  La Grave
#  La Grave - La Meije
#  La Salette
#  Le Chazelet
#  Le Collet d Allevard
#  Le Collet d Allevard -
#  Le Corbier
#  Le Corbier -S-
#  Le Rivier d Allemond
#  Les 2 ALpes Jandri
#  Les 2 Alpes (GN)
#  Les 2 Alpes (Pied Mout
#  Les 2 Alpes (Pied Mout
#  Les 2 Alpes (Toura NE)
#  Les 2 Alpes (Toura NE)
#  Les Karellis
#  Les Karellis -S-
#  MONTGENEVRE
#  MONTGENEVRE GENDARMERI
#  MONTGENEVRE-LE CHALVET
#  MONTSAPEY
#  Montgenevre_Alpet -S-
#  NEVACHE
#  NEVACHE-BUFFERE
#  Nevache
#  ORNON
#  Olmet
#  PRAPOUTEL
#  Peyroux d Amont -S-
#  Prapoutel
#  Prapoutel
#  Prapoutel -S-
#  Prapoutel Pipay
#  ST ALBAN DES VI
#  ST COLOMBAN DES VILLAR
#  ST FRANCOIS LONG
#  ST JEAN D ARVES
#  ST SORLIN -S-
#  ST SORLIN D'ARVES
#  ST-CHRISTOPHE
#  ST-MICHEL DE MAURIENNE
#  ST-SORLIN D'ARVES
#  St Christophe
#  St Francois Longchamp
#  VALJOUFFREY
#  VALLOIRE FOREST
#  VALLOIRE-CL
#  VALMEINIER -S-
#  VAUJANY
#  VAUJANY-NIVO
#  VILLAR D'ARENE
#  Valloire
#  Valloire -S-
#  Valmeinier
#  Vaujany -S-
# number of selected posts:  95
# common postes between metadata and csv : 33
# [' LAC NOIR-EDFNIVO ', ' LA MEIJE-NIVOSE ', ' GALIBIER-NIVOSE ', ' MONTGENEVRE GENDARMERI ', ' MONTGENEVRE-LE CHALVET ', ' CHARDONNET-EDFNIVO ', ' NEVACHE-BUFFERE ', " VILLAR D'ARENE ", ' BARDONECCHIA_PIAN_DEL_ ', ' CHATEAU_BEAULARD ', ' PRAPOUTEL ', ' AIGLETON-NIVOSE ', ' Le Collet d Allevard ', ' AURIS-EN-OISANS ', ' AGNELIN-EDFNIVO ', ' L Alpe d Huez (SATA) ', ' L Alpe d Huez 2350 ', ' Les 2 Alpes (Toura NE) ', ' L Alpe du Grand Serre ', ' Olmet ', ' St Christophe ', ' LES ECRINS-NIVOSE ', ' COL DU BARIOZ ', ' VAUJANY-NIVO ', ' CHAMROUSSE ARSELLE ', ' Chamrousse Niverolles ', ' Les Karellis ', ' BISSORTE-EDFNIVO ', ' ST FRANCOIS LONG ', ' LES ROCHILLES-NIVOSE ', ' Valloire ', ' Valmeinier ', ' Le Corbier ']
# cols Index([' LAC NOIR-EDFNIVO ', ' LA MEIJE-NIVOSE ', ' GALIBIER-NIVOSE ',
#        ' MONTGENEVRE GENDARMERI ', ' MONTGENEVRE-LE CHALVET ',
#        ' CHARDONNET-EDFNIVO ', ' NEVACHE-BUFFERE ', ' VILLAR D'ARENE ',
#        ' BARDONECCHIA_PIAN_DEL_ ', ' CHATEAU_BEAULARD ', ' PRAPOUTEL ',
#        ' AIGLETON-NIVOSE ', ' Le Collet d Allevard ', ' AURIS-EN-OISANS ',
#        ' AGNELIN-EDFNIVO ', ' L Alpe d Huez (SATA) ', ' L Alpe d Huez 2350 ',
#        ' Les 2 Alpes (Toura NE) ', ' L Alpe du Grand Serre ', ' Olmet ',
#        ' St Christophe ', ' LES ECRINS-NIVOSE ', ' COL DU BARIOZ ',
#        ' VAUJANY-NIVO ', ' CHAMROUSSE ARSELLE ', ' Chamrousse Niverolles ',
#        ' Les Karellis ', ' BISSORTE-EDFNIVO ', ' ST FRANCOIS LONG ',
#        ' LES ROCHILLES-NIVOSE ', ' Valloire ', ' Valmeinier ', ' Le Corbier '],
#       dtype='object', name='NUMPOST')
# number of observed posts: 33

# %%
df.columns
# Out:
# Index([' LAC NOIR-EDFNIVO ', ' LA MEIJE-NIVOSE ', ' GALIBIER-NIVOSE ',
#        ' MONTGENEVRE GENDARMERI ', ' MONTGENEVRE-LE CHALVET ',
#        ' CHARDONNET-EDFNIVO ', ' NEVACHE-BUFFERE ', ' VILLAR D'ARENE ',
#        ' BARDONECCHIA_PIAN_DEL_ ', ' CHATEAU_BEAULARD ', ' PRAPOUTEL ',
#        ' AIGLETON-NIVOSE ', ' Le Collet d Allevard ', ' AURIS-EN-OISANS ',
#        ' AGNELIN-EDFNIVO ', ' L Alpe d Huez (SATA) ', ' L Alpe d Huez 2350 ',
#        ' Les 2 Alpes (Toura NE) ', ' L Alpe du Grand Serre ', ' Olmet ',
#        ' St Christophe ', ' LES ECRINS-NIVOSE ', ' COL DU BARIOZ ',
#        ' VAUJANY-NIVO ', ' CHAMROUSSE ARSELLE ', ' Chamrousse Niverolles ',
#        ' Les Karellis ', ' BISSORTE-EDFNIVO ', ' ST FRANCOIS LONG ',
#        ' LES ROCHILLES-NIVOSE ', ' Valloire ', ' Valmeinier ', ' Le Corbier '],
#       dtype='object', name='NUMPOST')
